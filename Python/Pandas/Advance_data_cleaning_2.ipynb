# %% [markdown]
# 📚 Extended Pandas Learning Path
#
# 14. Pivot Table      → Excel-style summary tables
# 15. Crosstab         → frequency/comparison tables
# 16. String Methods   → str.lower(), str.contains(), str.split()
# 17. MultiIndex       → multiple row/column labels
# 18. Categorical Data → memory-efficient label data
# 19. Styling          → color, highlight DataFrames visually
# 20. Window Functions → rolling(), expanding() for trends
# 21. Pipe & Chaining  → clean, readable code flow
# 22. Memory Optim.    → reduce RAM usage on big data
# 23. Large Datasets   → chunking big files
# 24. Integration      → connect with NumPy, Matplotlib, Sklearn
